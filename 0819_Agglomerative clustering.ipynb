# %% [markdown]
# ## 병합군집

# %% [markdown]
# - 저장된 갯수의 클러스터가 남을 때 까지 비슷한 클러스터를 합친다.
# - 따라서 종료 조건은 주어진 클러스터의 갯수
# - sklearn / Scipy 두 종류가 있음
#     - sklearn의 경우
#         - ward : 모든 클러스터 내의 분산을 가장 작게 증가시키는 클러스터를 합친다.
#         - average : 포인트 사이의 평균 거리가 가장 짧은 두 클러스터를 합친다
#         - complete : 클러스터 포인트 사이에 최대 거리가 가장 짧은 두 클러스터를 합친다
#     - scipy
# - predict 메쏘드가 없다.
#     - 훈련 세트로 모델을 만들고 클러스터 소속 정보를 얻기 위해 fit_predict 메쏘드를 사용 합니다.
# - 계층 군집의 시각화를 위해선 덴드로그램을 써야하는데 이는 사이킥런에 없으므로 싸이파이를 사용하자
# - 덴드로그램에서 가지의 길이는 포인트 들이 얼마나 멀리 떨어져 있는지를 나타낸다

# %% [markdown]
# 1. 임포트 하기 : sklearn / scipy
#     - from sklearn.cluster import AgglomerativeClustering
#     - from scipy.cluster.hierarchy import dendrogram, ward
#
# 2. 모델 적용하기
#     - agg = AgglomerativeClustering(n_clusters = num)
#         - num = 클러스터 갯수(종료조건)
#         - sklearn
#     - linkage_array = ward(X)
#         - scipy
# 3. 모델 확인하기
#     - agg.fit_predict(X)
#     - dendrogram(linkage_array)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import mglearn

# %%
mglearn.plots.plot_agglomerative_algorithm()

# %%
from sklearn.cluster import AgglomerativeClustering
X, y = make_blobs(random_state= 1)

# %%
from sklearn.datasets import make_blobs

# %%
assignment
# Out:
# array([0, 2, 2, 2, 1, 1, 1, 2, 0, 0, 2, 2, 1, 0, 1, 1, 1, 0, 2, 2, 1, 2, 1,
#        0, 2, 1, 1, 0, 0, 1, 0, 0, 1, 0, 2, 1, 2, 2, 2, 1, 1, 2, 0, 2, 2, 1,
#        0, 0, 0, 0, 2, 1, 1, 1, 0, 1, 2, 2, 0, 0, 2, 1, 1, 2, 2, 1, 0, 1, 0,
#        2, 2, 2, 1, 0, 0, 2, 1, 1, 0, 2, 0, 2, 2, 1, 0, 0, 0, 0, 2, 0, 1, 0,
#        0, 2, 2, 1, 1, 0, 1, 0], dtype=int64)

# %%
from sklearn.cluster import AgglomerativeClustering
X, y = make_blobs(random_state= 1)

agg = AgglomerativeClustering(n_clusters = 3)
assignment = agg.fit_predict(X)

mglearn.discrete_scatter(X[:, 0], X[:, 1], assignment)
plt.legend(['cluster 0', 'cluster 1', 'cluster 2'], loc = 'best')
plt.xlabel('cha 0')
plt.ylabel('cha 1')

# %%
from sklearn.cluster import KMeans

# %%
kmean = KMeans(n_clusters = 3)
kmean.fit(X)
exe = kmean.predict(X)

# %%
mglearn.discrete_scatter(X[:, 0], X[:,1], exe)
plt.legend(['k1', 'k2', 'k3'], loc = 'best')

# %%
mglearn.plots.plot_agglomerative()

# %%
from scipy.cluster.hierarchy import dendrogram, ward

# %%
bounds
# Out:
# (0.0, 120.0)

# %%
X, y = make_blobs(random_state = 0, n_samples = 12)

linkage_array = ward(X)

dendrogram(linkage_array)

ax = plt.gca()
bounds = ax.get_xbound()
ax.plot(bounds, [7.25, 7.25], '--', c = 'k')
ax.plot(bounds, [4,4], '--', c='k')

ax.text(bounds[1], 7.25, 'two cluster', va = 'center', fontdict = {'size' : 15})
ax.text(bounds[1], 4, 'three cluster', va = 'center', fontdict = {'size' : 15})
plt.xlabel('sample')
plt.ylabel('cluster distance')
